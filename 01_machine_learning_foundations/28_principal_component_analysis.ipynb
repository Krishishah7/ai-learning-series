# %% [markdown]
# <a href="https://colab.research.google.com/github/Krishishah7/ai-learning-series/blob/main/01_machine_learning_foundations/28_principal_component_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Principal Component Analysis (PCA)
#
# In this notebook, we use PCA to reduce dataset dimensions while preserving maximum variance.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.datasets import make_classification

from sklearn.preprocessing import StandardScaler

from sklearn.decomposition import PCA

# %%
X, y = make_classification(
    n_samples=200,
    n_features=5,
    n_informative=3,
    random_state=42
)

# %%
print("Original Shape:")

print(X.shape)
# Out:
# Original Shape:
# (200, 5)

# %%
scaler = StandardScaler()

X_scaled = scaler.fit_transform(X)

# %%
pca = PCA(n_components=2)

X_pca = pca.fit_transform(X_scaled)

# %%
print("PCA Shape:")

print(X_pca.shape)
# Out:
# PCA Shape:
# (200, 2)

# %%
print(
    pca.explained_variance_ratio_
)
# Out:
# [0.46531379 0.40295972]

# %%
print(
    "Total Variance:",
    pca.explained_variance_ratio_.sum()
)
# Out:
# Total Variance: 0.8682735124813805

# %%
plt.figure(figsize=(8,6))

plt.scatter(
    X_pca[:,0],
    X_pca[:,1],
    c=y,
    s=70
)

plt.xlabel("Principal Component 1")

plt.ylabel("Principal Component 2")

plt.title("PCA Projection")

plt.show()

# %%
comparison = pd.DataFrame({
    "Dataset":[
        "Original",
        "After PCA"
    ],
    "Features":[
        X.shape[1],
        X_pca.shape[1]
    ]
})

comparison
# Out:
#      Dataset  Features
# 0   Original         5
# 1  After PCA         2
