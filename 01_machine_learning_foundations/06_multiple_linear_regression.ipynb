# %% [markdown]
# <a href="https://colab.research.google.com/github/Krishishah7/ai-learning-series/blob/main/01_machine_learning_foundations/06_multiple_linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Multiple Linear Regression
#
# In this notebook, we use multiple input features to predict an output value using Multiple Linear Regression.

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression

# %%
data = {
    "Hours_Studied": [1, 2, 3, 4, 5],
    "Sleep_Hours": [8, 7, 6, 6, 5],
    "Exam_Score": [50, 55, 65, 70, 80]
}

df = pd.DataFrame(data)

df
# Out:
#    Hours_Studied  Sleep_Hours  Exam_Score
# 0              1            8          50
# 1              2            7          55
# 2              3            6          65
# 3              4            6          70
# 4              5            5          80

# %%
X = df[["Hours_Studied", "Sleep_Hours"]]
y = df["Exam_Score"]

# %%
model = LinearRegression()

model.fit(X, y)
# Out:
# LinearRegression()

# %%
predictions = model.predict(X)

predictions
# Out:
# array([48.66666667, 56.66666667, 64.66666667, 71.        , 79.        ])

# %%
print("Coefficients:", model.coef_)
print("Intercept:", model.intercept_)
# Out:
# Coefficients: [ 6.33333333 -1.66666667]
# Intercept: 55.666666666666664

# %%
new_data = pd.DataFrame({
    "Hours_Studied": [6],
    "Sleep_Hours": [7]
})

prediction = model.predict(new_data)

print(prediction)
# Out:
# [82.]

# %%
import matplotlib.pyplot as plt

plt.scatter(y, predictions)

plt.xlabel("Actual Exam Score")
plt.ylabel("Predicted Exam Score")

plt.title("Actual vs Predicted Scores")

plt.plot([y.min(), y.max()],
         [y.min(), y.max()],
         color='red')

plt.show()
