# %% [markdown]
# <a href="https://colab.research.google.com/github/Krishishah7/ai-learning-series/blob/main/01_machine_learning_foundations/05_learning_rate_experiment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Learning Rate Experiment
#
# In this notebook, we explore how different learning rates affect Gradient Descent and model convergence.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
X = np.array([1, 2, 3, 4, 5])
y = np.array([2, 4, 6, 8, 10])

# %%
def gradient_descent(learning_rate):

    m = 0
    b = 0
    epochs = 50
    n = len(X)

    losses = []

    for i in range(epochs):

        y_pred = m * X + b

        mse = np.mean((y - y_pred) ** 2)
        losses.append(mse)

        dm = (-2/n) * np.sum(X * (y - y_pred))
        db = (-2/n) * np.sum(y - y_pred)

        m = m - learning_rate * dm
        b = b - learning_rate * db

    return losses

# %%
loss_small = gradient_descent(0.001)
loss_good = gradient_descent(0.01)
loss_large = gradient_descent(1)

# %%
plt.plot(loss_small, label="0.001")
plt.plot(loss_good, label="0.01")
plt.plot(loss_large, label="1")

plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Learning Rate Comparison")

plt.yscale("log")

plt.legend()
plt.show()
